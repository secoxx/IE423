# %% [markdown]
# <a href="https://colab.research.google.com/github/secoxx/IE423/blob/main/task_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Initialize

# %%
# !pip install transformers

# %%
pip install evaluate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 33.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 17.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ...

# %%
# Use pipelines to access pre-trained models
from transformers import pipeline
from transformers.pipelines.pt_utils import KeyDataset
import evaluate

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score

# %% [markdown]
# ## Sentiment Analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We'll load a yelp reviews dataset we imported from Sentiment Labelled Sentences
# dataset of UC Irvine. It has two columns: review and label. Label denotes the sentiment of the review: 1 denotes positive and 0 denotes negative.

# %%
# Model
mdlSnt = pipeline('sentiment-analysis')

#Dataframe
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/sentiment/yelp_labelled.txt',sep='\t',header=None)
df.columns = ["Review","Label"]
df.head()
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
#                                               Review  Label
# 0                           Wow... Loved this place.      1
# 1                                 Crust is not good.      0
# 2          Not tasty and the texture was just nasty.      0
# 3  Stopped by during the late May bank holiday of...      1
# 4  The selection on the menu was great and so wer...      1

# %%
reviews = df['Review'].to_list()
predictions = mdlSnt(reviews)
predictions[:10]
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998804330825806},
#  {'label': 'NEGATIVE', 'score': 0.9997690320014954},
#  {'label': 'NEGATIVE', 'score': 0.9996275901794434},
#  {'label': 'POSITIVE', 'score': 0.9995303153991699},
#  {'label': 'POSITIVE', 'score': 0.9996086955070496},
#  {'label': 'NEGATIVE', 'score': 0.992295503616333},
#  {'label': 'NEGATIVE', 'score': 0.9909782409667969},
#  {'label': 'NEGATIVE', 'score': 0.9024141430854797},
#  {'label': 'POSITIVE', 'score': 0.9997226595878601},
#  {'label': 'POSITIVE', 'score': 0.9998835325241089}]

# %%
df['Label'].head(10)
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    1
# 5    0
# 6    0
# 7    0
# 8    1
# 9    1
# Name: Label, dtype: int64

# %% [markdown]
# The first 10 instances are all predicted correctly.

# %%
# Model
mdlSnt = pipeline('sentiment-analysis', model = 'nlptown/bert-base-multilingual-uncased-sentiment')

mdlSnt(reviews)[:10]
# Out:
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/669M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': '5 stars', 'score': 0.9040048122406006},
#  {'label': '2 stars', 'score': 0.4416303038597107},
#  {'label': '2 stars', 'score': 0.5507872104644775},
#  {'label': '5 stars', 'score': 0.44384071230888367},
#  {'label': '5 stars', 'score': 0.43093574047088623},
#  {'label': '5 stars', 'score': 0.5807459950447083},
#  {'label': '2 stars', 'score': 0.3195105493068695},
#  {'label': '3 stars', 'score': 0.38606229424476624},
#  {'label': '5 stars', 'score': 0.6109557151794434},
# ...

# %%
def sentiment_evaluate(model_name):
    true_labels = df['Label'].to_list()
    pred_labels= [1 if prediction["label"].lower()=="positive" else 0 for prediction in predictions]

    accuracy_metric = evaluate.load("accuracy")
    accuracy = accuracy_metric.compute(predictions=pred_labels, references=true_labels)
    print(f"For {len(true_labels)} datapoints the accuracy for the sentiment analysis model is {accuracy['accuracy']} ")

sentiment_evaluate(mdlSnt)
# Out:
# For 1000 datapoints the accuracy for the sentiment analysis model is 0.924

# %% [markdown]
# We evaluated the first model and obtained a 92% accuracy.

# %% [markdown]
# ## Question Answering

# %% [markdown]
# We'll load the SQuAD (Stanford Question Answering Dataset) dataset from HF's repository.

# %%
splits = {'train': 'plain_text/train-00000-of-00001.parquet', 'validation': 'plain_text/validation-00000-of-00001.parquet'}
df = pd.read_parquet("hf://datasets/rajpurkar/squad/" + splits["train"])

# %%
df.head()
# Out:
#                          id                     title  \
# 0  5733be284776f41900661182  University_of_Notre_Dame
# 1  5733be284776f4190066117f  University_of_Notre_Dame
# 2  5733be284776f41900661180  University_of_Notre_Dame
# 3  5733be284776f41900661181  University_of_Notre_Dame
# 4  5733be284776f4190066117e  University_of_Notre_Dame
#
#                                              context  \
# 0  Architecturally, the school has a Catholic cha...
# 1  Architecturally, the school has a Catholic cha...
# 2  Architecturally, the school has a Catholic cha...
# 3  Architecturally, the school has a Catholic cha...
# 4  Architecturally, the school has a Catholic cha...
#
#                                             question  \
# 0  To whom did the Virgin Mary allegedly appear i...
# 1  What is in front of the Notre Dame Main Building?
# 2  The Basilica of the Sacred heart at Notre Dame...
# 3                  What is the Grotto at Notre Dame?
# ...

# %%
df_first10 = df.loc[:10]

# %%
# Model
mdlQa = pipeline("question-answering")
# Predict
answers = mdlQa(question = df_first10['question'].to_list(), context = df_first10['context'].to_list())
answers[:10]
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'score': 0.995937705039978,
#   'start': 515,
#   'end': 541,
#   'answer': 'Saint Bernadette Soubirous'},
#  {'score': 0.3604850172996521,
#   'start': 188,
#   'end': 213,
#   'answer': 'a copper statue of Christ'},
#  {'score': 0.23104910552501678,
#   'start': 279,
#   'end': 296,
#   'answer': 'the Main Building'},
#  {'score': 0.939583420753479,
#   'start': 381,
#   'end': 420,
#   'answer': 'a Marian place of prayer and reflection'},
#  {'score': 0.37197166681289673,
#   'start': 92,
#   'end': 126,
#   'answer': 'a golden statue of the Virgin Mary'},
# ...

# %%
df['answers'].values
# Out:
# array([{'text': array(['Saint Bernadette Soubirous'], dtype=object), 'answer_start': array([515], dtype=int32)},
#        {'text': array(['a copper statue of Christ'], dtype=object), 'answer_start': array([188], dtype=int32)},
#        {'text': array(['the Main Building'], dtype=object), 'answer_start': array([279], dtype=int32)},
#        ...,
#        {'text': array(['Minsk'], dtype=object), 'answer_start': array([476], dtype=int32)},
#        {'text': array(['1975'], dtype=object), 'answer_start': array([199], dtype=int32)},
#        {'text': array(['Kathmandu Metropolitan City'], dtype=object), 'answer_start': array([0], dtype=int32)}],
#       dtype=object)

# %%
def normalize_answer(s):
    """Lower text and remove punctuation, articles and extra whitespace."""
    import re
    import string

    def remove_articles(text):
        return re.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        return ''.join(ch for ch in text if ch not in set(string.punctuation))

    def lower(text):
        return text.lower()

    return white_space_fix(remove_articles(remove_punc(lower(s))))

def f1_score_single(prediction, ground_truth):
    pred_tokens = normalize_answer(prediction).split()
    truth_tokens = normalize_answer(ground_truth).split()
    common_tokens = set(pred_tokens) & set(truth_tokens)
    if not common_tokens:
        return 0
    prec = len(common_tokens) / len(pred_tokens)
    rec = len(common_tokens) / len(truth_tokens)
    return 2 * (prec * rec) / (prec + rec)

def exact_match_score(prediction, ground_truth):
    return normalize_answer(prediction) == normalize_answer(ground_truth)

def qa_evaluate(df, answers):
    pred_answers = [answer["answer"] for answer in answers]
    true_answers = [answer["text"][0] for answer in df['answers'].values]

    exact_matches = [exact_match_score(p, t) for p, t in zip(pred_answers, true_answers)]
    f1_scores = [f1_score_single(p, t) for p, t in zip(pred_answers, true_answers)]

    exact_match = np.mean(exact_matches)
    avg_f1_score = np.mean(f1_scores)

    return {
        "exact_match": exact_match,
        "f1_score": avg_f1_score
    }

# Evaluate
evaluation_results = qa_evaluate(df_first10, answers)
print(evaluation_results)
# Out:
# {'exact_match': 0.9090909090909091, 'f1_score': 0.9696969696969696}

# %% [markdown]
# When we evaluate the accuracy of our qa model for the first 10 instances, we get a 96% f1 score and 90% exact match.
